# %%
import pandas as pd
import glob

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

client_id = '55e915e6dc2549b29feb68ef4e611e2a'
client_secret = '086669968e7e4892bc08c8d39308afaf'
username="21ulbu67tca2mhvh2jiy3g4da"

# %%
token = util.prompt_for_user_token(
    username="21ulbu67tca2mhvh2jiy3g4da",
    scope='user-read-playback-state,playlist-read-private,user-modify-playback-state,playlist-modify-public', 
    client_id = '55e915e6dc2549b29feb68ef4e611e2a',
    client_secret = '086669968e7e4892bc08c8d39308afaf',
    redirect_uri="http://localhost:8889/callback"
)
sp = spotipy.Spotify(auth=token)

# %%
files = glob.glob("./playlists/*.csv")
file = files[1]

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#     Unnamed: 0  index_x                      id  \
# 0            0        0  7qL7yiDtoOrebjZLK4Vfgx
# 1            1        0  4Keq8d63cPQyTjsxcSmumj
# 2            2        0  5yQqZ8ZGLSvU1Y0clnHG3C
# 3            3        0  0weAUscowxeqDtpCgtbpgp
# 4            4        0  0v6ZkVp2N6UQffv198Kn01
# 5            5        0  0L2DHyqL5HkV34dSCylYgN
# 6            6       13  5dQoiFgCihmn0a20e92xMZ
# 7            7       28  1HgM1NOTcUQ3RAJszQCw03
# 8            8        0  4pJyvYP5klY5DK84dN3q90
# 9            9        0  1QMi9XPFQAlgtkAdvDBmAy
# 10          10        0  3gDL3aHnWzcJYjJjjjT5sV
# 11          11        0  3j5X0W7g5n3A6tzmaqtCei
# 12          12        0  2JP7p3KiVmCwYMzs0xxltq
# 13          13        0  72iUWrYQg8cGRk8cHUramY
# 14          14        0  4ARnte9zRykgVqto6j7LMp
# 15          15        0  3JA9Jsuxr4xgHXEawAdCp4
#
#                                                 track  \
# 0            La Isla Bonita - Mad Morello & Igi Remix
# 1    Praise You - Purple Disco Machine Extended Remix
# 2   He's the Greatest Dancer - Dimitri from Paris ...
# 3                                Gettin' Jiggy Wit It
# 4                                        Jackin Souls
# 5   You’re the Only Good Thing (That’s Happened to...
# 6             Let's Play House - Laurent Simeca Remix
# 7                                    Body Funk - Edit
# 8   Joys - Purple Disco Machine Extended Remix (Mi...
# 9                                          EASY TASTY
# 10                         Sister - Original Club Mix
# 11                                                SOS
# 12                       Time Out - Original Club Mix
# 13                         That's the Way (I Like It)
# 14                      Superstition - Single Version
# 15                              Just Can’t Get Enough
#
#                                      artist  match  index_y  acousticness  \
# 0   Dual Disco/Kaprila Keishing/Mad Morello      2        0      0.003940
# 1          Fatboy Slim/Purple Disco Machine      1        0      0.030700
# 2          Sister Sledge/Dimitri From Paris      1        0      0.017000
# 3                                Will Smith      0        0      0.017500
# 4                 Block/Martina Budde/Crown      3        0      0.000495
# 5                             George Morgan      0        0      0.749000
# 6                Crazibiza/House of Prayers      1        0      0.000595
# 7                      Purple Disco Machine      1        0      0.009530
# 8       Roberto Surace/Purple Disco Machine      1        0      0.002250
# 9                                    Da-iCE      0        0      0.043900
# 10                       Me & My Toothbrush      0        0      0.038500
# 11                        Avicii/Aloe Blacc      0        0      0.302000
# 12                       Me & My Toothbrush      0        0      0.000610
# 13                   KC & The Sunshine Band      0        0      0.160000
# 14                            Stevie Wonder      0        0      0.017300
# 15                          Black Eyed Peas      0        0      0.186000
#
#                                          analysis_url  danceability  ...  \
# 0   https://api.spotify.com/v1/audio-analysis/7qL7...         0.832  ...
# 1   https://api.spotify.com/v1/audio-analysis/4Keq...         0.819  ...
# 2   https://api.spotify.com/v1/audio-analysis/5yQq...         0.737  ...
# 3   https://api.spotify.com/v1/audio-analysis/0weA...         0.881  ...
# 4   https://api.spotify.com/v1/audio-analysis/0v6Z...         0.728  ...
# 5   https://api.spotify.com/v1/audio-analysis/0L2D...         0.658  ...
# 6   https://api.spotify.com/v1/audio-analysis/5dQo...         0.783  ...
# 7   https://api.spotify.com/v1/audio-analysis/1HgM...         0.804  ...
# 8   https://api.spotify.com/v1/audio-analysis/4pJy...         0.779  ...
# 9   https://api.spotify.com/v1/audio-analysis/1QMi...         0.687  ...
# 10  https://api.spotify.com/v1/audio-analysis/3gDL...         0.868  ...
# 11  https://api.spotify.com/v1/audio-analysis/3j5X...         0.802  ...
# 12  https://api.spotify.com/v1/audio-analysis/2JP7...         0.813  ...
# 13  https://api.spotify.com/v1/audio-analysis/72iU...         0.685  ...
# 14  https://api.spotify.com/v1/audio-analysis/4ARn...         0.637  ...
# 15  https://api.spotify.com/v1/audio-analysis/3JA9...         0.659  ...
#
#     liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0     0.0467    -7.334     1       0.0656  118.010               4
# 1     0.0150    -6.094     1       0.0400  121.013               4
# 2     0.3170    -8.525     0       0.0433  117.019               4
# 3     0.1540    -4.505     1       0.1390  107.891               4
# 4     0.2140    -4.451     1       0.1220  124.046               4
# 5     0.0689   -15.514     1       0.0301   95.008               3
# 6     0.3260    -2.749     0       0.1540  123.992               4
# 7     0.0808    -6.490     1       0.0409  121.995               4
# 8     0.1990    -4.987     1       0.0396  123.468               4
# 9     0.0551    -3.346     0       0.1200  122.961               4
# 10    0.2710    -4.186     1       0.0643  121.001               4
# 11    0.1180    -6.121     0       0.0591   99.978               4
# 12    0.0636    -4.879     1       0.0477  124.011               4
# 13    0.3290    -9.031     0       0.0394  108.662               4
# 14    0.0372    -8.607     1       0.0748  100.384               4
# 15    0.1050    -8.685     0       0.1790   94.050               4
#
#                                            track_href            type  \
# 0   https://api.spotify.com/v1/tracks/7qL7yiDtoOre...  audio_features
# 1   https://api.spotify.com/v1/tracks/4Keq8d63cPQy...  audio_features
# 2   https://api.spotify.com/v1/tracks/5yQqZ8ZGLSvU...  audio_features
# 3   https://api.spotify.com/v1/tracks/0weAUscowxeq...  audio_features
# 4   https://api.spotify.com/v1/tracks/0v6ZkVp2N6UQ...  audio_features
# 5   https://api.spotify.com/v1/tracks/0L2DHyqL5HkV...  audio_features
# 6   https://api.spotify.com/v1/tracks/5dQoiFgCihmn...  audio_features
# 7   https://api.spotify.com/v1/tracks/1HgM1NOTcUQ3...  audio_features
# 8   https://api.spotify.com/v1/tracks/4pJyvYP5klY5...  audio_features
# 9   https://api.spotify.com/v1/tracks/1QMi9XPFQAlg...  audio_features
# 10  https://api.spotify.com/v1/tracks/3gDL3aHnWzcJ...  audio_features
# 11  https://api.spotify.com/v1/tracks/3j5X0W7g5n3A...  audio_features
# 12  https://api.spotify.com/v1/tracks/2JP7p3KiVmCw...  audio_features
# 13  https://api.spotify.com/v1/tracks/72iUWrYQg8cG...  audio_features
# 14  https://api.spotify.com/v1/tracks/4ARnte9zRykg...  audio_features
# 15  https://api.spotify.com/v1/tracks/3JA9Jsuxr4xg...  audio_features
#
#                                      uri valence
# 0   spotify:track:7qL7yiDtoOrebjZLK4Vfgx   0.704
# 1   spotify:track:4Keq8d63cPQyTjsxcSmumj   0.930
# 2   spotify:track:5yQqZ8ZGLSvU1Y0clnHG3C   0.586
# 3   spotify:track:0weAUscowxeqDtpCgtbpgp   0.858
# 4   spotify:track:0v6ZkVp2N6UQffv198Kn01   0.629
# 5   spotify:track:0L2DHyqL5HkV34dSCylYgN   0.300
# 6   spotify:track:5dQoiFgCihmn0a20e92xMZ   0.870
# 7   spotify:track:1HgM1NOTcUQ3RAJszQCw03   0.922
# 8   spotify:track:4pJyvYP5klY5DK84dN3q90   0.720
# 9   spotify:track:1QMi9XPFQAlgtkAdvDBmAy   0.581
# 10  spotify:track:3gDL3aHnWzcJYjJjjjT5sV   0.880
# 11  spotify:track:3j5X0W7g5n3A6tzmaqtCei   0.389
# 12  spotify:track:2JP7p3KiVmCwYMzs0xxltq   0.487
# 13  spotify:track:72iUWrYQg8cGRk8cHUramY   0.914
# 14  spotify:track:4ARnte9zRykgVqto6j7LMp   0.859
# 15  spotify:track:3JA9Jsuxr4xgHXEawAdCp4   0.262
#
# [16 rows x 23 columns]
